# %%
import pandas as pd
import numpy as np

# %%
namebasics = pd.read_csv('name.basics.tsv.gz',usecols=['primaryProfession', 'nconst', 'primaryName'], sep = '\t')

# %%
namebasics
# Out:
#              nconst         primaryName                    primaryProfession
# 0         nm0000001        Fred Astaire       soundtrack,actor,miscellaneous
# 1         nm0000002       Lauren Bacall                   actress,soundtrack
# 2         nm0000003     Brigitte Bardot  actress,soundtrack,music_department
# 3         nm0000004        John Belushi              actor,soundtrack,writer
# 4         nm0000005      Ingmar Bergman                writer,director,actor
# ...             ...                 ...                                  ...
# 11531344  nm9993714   Romeo del Rosario  animation_department,art_department
# 11531345  nm9993716       Essias Loberg                                  NaN
# 11531346  nm9993717  Harikrishnan Rajan                      cinematographer
# 11531347  nm9993718         Aayush Nair                      cinematographer
# 11531348  nm9993719          Andre Hill                                  NaN
#
# [11531349 rows x 3 columns]

# %%
#namebasics = namebasics.astype({"primaryProfession": str})

namebasics.dtypes
# Out:
# nconst               object
# primaryName          object
# primaryProfession    object
# dtype: object

# %%
namebasics["primaryProfession"] = namebasics["primaryProfession"].str.split(",")

# %%
namebasics.explode('primaryProfession')
# Out:
#              nconst         primaryName primaryProfession
# 0         nm0000001        Fred Astaire        soundtrack
# 0         nm0000001        Fred Astaire             actor
# 0         nm0000001        Fred Astaire     miscellaneous
# 1         nm0000002       Lauren Bacall           actress
# 1         nm0000002       Lauren Bacall        soundtrack
# ...             ...                 ...               ...
# 11531344  nm9993714   Romeo del Rosario    art_department
# 11531345  nm9993716       Essias Loberg               NaN
# 11531346  nm9993717  Harikrishnan Rajan   cinematographer
# 11531347  nm9993718         Aayush Nair   cinematographer
# 11531348  nm9993719          Andre Hill               NaN
#
# [14981996 rows x 3 columns]

# %%
titleprincipals = pd.read_csv('title.principals.tsv.gz',usecols=['category', 'nconst', 'tconst'], sep = '\t')

# %%
titleprincipals
# Out:
#              tconst      nconst         category
# 0         tt0000001   nm1588970             self
# 1         tt0000001   nm0005690         director
# 2         tt0000001   nm0374658  cinematographer
# 3         tt0000002   nm0721526         director
# 4         tt0000002   nm1335271         composer
# ...             ...         ...              ...
# 49736919  tt9916880  nm10535738          actress
# 49736920  tt9916880   nm0996406         director
# 49736921  tt9916880   nm1482639           writer
# 49736922  tt9916880   nm2586970           writer
# 49736923  tt9916880   nm1594058         producer
#
# [49736924 rows x 3 columns]

# %%
titlesbasics = pd.read_csv('title.basics.tsv.gz',usecols=['primaryTitle', 'genres', 'tconst', 'titleType'], sep = '\t')

# %%
titlesbasics.value_counts('titleType')
# Out:
# titleType
# tvEpisode       6616225
# short            863404
# movie            606395
# video            258969
# tvSeries         223071
# tvMovie          135614
# tvMiniSeries      42849
# tvSpecial         36476
# videoGame         30824
# tvShort           10512
# tvPilot               2
# dtype: int64

# %%
titlesMOVIESshortsvids = titlesbasics[titlesbasics["titleType"].isin(['short','movie', 'video', 'tvMovie'])]

# %%
titlesMOVIESshortsvids.value_counts('titleType')
# Out:
# titleType
# short      863404
# movie      606395
# video      258969
# tvMovie    135614
# dtype: int64

# %%
titlesMOVIESshortsvids
# Out:
#             tconst titleType                    primaryTitle       genres
# 0        tt0000001     short                      Carmencita  Documentary
# 0        tt0000001     short                      Carmencita        Short
# 1        tt0000002     short          Le clown et ses chiens    Animation
# 1        tt0000002     short          Le clown et ses chiens        Short
# 2        tt0000003     short                  Pauvre Pierrot    Animation
# ...            ...       ...                             ...          ...
# 8824281  tt9916730     movie                          6 Gunn           \N
# 8824291  tt9916754     movie  Chico Albuquerque - Revelações  Documentary
# 8824292  tt9916756     short        Pretty Pretty Black Girl        Short
# 8824296  tt9916764     short                              38        Short
# 8824339  tt9916856     short                        The Wind        Short
#
# [3227081 rows x 4 columns]

# %%
titleRatings = pd.read_csv('title.ratings.tsv.gz', sep = '\t')
titleRatingsSrtd = titleRatings.sort_values( by=['numVotes', 'averageRating'], ascending= False )
titleRatingsSrtd
# Out:
#             tconst  averageRating  numVotes
# 82505    tt0111161            9.3   2569002
# 251029   tt0468569            9.1   2534021
# 629117   tt1375666            8.8   2254701
# 99118    tt0137523            8.8   2021525
# 81412    tt0109830            8.8   1981606
# ...            ...            ...       ...
# 1154310  tt7813152            1.0         5
# 1163644  tt8027962            1.0         5
# 1185034  tt8581078            1.0         5
# 1196843  tt8914192            1.0         5
# 1197669  tt8941352            1.0         5
#
# [1230952 rows x 3 columns]

# %%
titleRatingsSrtd['POP SCORE'] = titleRatingsSrtd['averageRating'] * titleRatingsSrtd['numVotes']

# %%
titleRatingsSrtd
# Out:
#             tconst  averageRating  numVotes   POP SCORE
# 82505    tt0111161            9.3   2569002  23891718.6
# 251029   tt0468569            9.1   2534021  23059591.1
# 629117   tt1375666            8.8   2254701  19841368.8
# 99118    tt0137523            8.8   2021525  17789420.0
# 81412    tt0109830            8.8   1981606  17438132.8
# ...            ...            ...       ...         ...
# 1154310  tt7813152            1.0         5         5.0
# 1163644  tt8027962            1.0         5         5.0
# 1185034  tt8581078            1.0         5         5.0
# 1196843  tt8914192            1.0         5         5.0
# 1197669  tt8941352            1.0         5         5.0
#
# [1230952 rows x 4 columns]

# %%
titlesBasicsRatings = titlesMOVIESshortsvids.merge(titleRatingsSrtd, how= 'left', on= 'tconst')

# %%
titleSRTDpop = titlesBasicsRatings.sort_values( by=['POP SCORE'], ascending= False )

# %%
titleSRTDpop.head(60)
# Out:
#             tconst titleType  \
# 178228   tt0111161     movie
# 628982   tt0468569     movie
# 628983   tt0468569     movie
# 628984   tt0468569     movie
# 1230027  tt1375666     movie
# 1230025  tt1375666     movie
# 1230026  tt1375666     movie
# 213498   tt0137523     movie
# 177822   tt0110912     movie
# 177823   tt0110912     movie
# 176087   tt0109830     movie
# 176086   tt0109830     movie
# 115746   tt0068646     movie
# 115745   tt0068646     movie
# 207726   tt0133093     movie
# 207727   tt0133093     movie
# 192125   tt0120737     movie
# 192126   tt0120737     movie
# 192124   tt0120737     movie
# 254844   tt0167260     movie
# 254845   tt0167260     movie
# 254846   tt0167260     movie
# 688949   tt0816692     movie
# 688948   tt0816692     movie
# 688950   tt0816692     movie
# 254847   tt0167261     movie
# 254849   tt0167261     movie
# 254848   tt0167261     movie
# 1187895  tt1345836     movie
# 1187896  tt1345836     movie
# 1187894  tt1345836     movie
# 182817   tt0114369     movie
# 182819   tt0114369     movie
# 182818   tt0114369     movie
# 1730222  tt1853728     movie
# 1730221  tt1853728     movie
# 260588   tt0172495     movie
# 260590   tt0172495     movie
# 260589   tt0172495     movie
# 166456   tt0102926     movie
# 166457   tt0102926     movie
# 166458   tt0102926     movie
# 173696   tt0108052     movie
# 173694   tt0108052     movie
# 173695   tt0108052     movie
# 513194   tt0372784     movie
# 513196   tt0372784     movie
# 513195   tt0372784     movie
# 192275   tt0120815     movie
# 192274   tt0120815     movie
# 497699   tt0361748     movie
# 497698   tt0361748     movie
# 497700   tt0361748     movie
# 127830   tt0076759     movie
# 127831   tt0076759     movie
# 127829   tt0076759     movie
# 120085   tt0071562     movie
# 120086   tt0071562     movie
# 646436   tt0482571     movie
# 646437   tt0482571     movie
#
#                                               primaryTitle     genres  \
# 178228                            The Shawshank Redemption      Drama
# 628982                                     The Dark Knight     Action
# 628983                                     The Dark Knight      Crime
# 628984                                     The Dark Knight      Drama
# 1230027                                          Inception     Sci-Fi
# 1230025                                          Inception     Action
# 1230026                                          Inception  Adventure
# 213498                                          Fight Club      Drama
# 177822                                        Pulp Fiction      Crime
# 177823                                        Pulp Fiction      Drama
# 176087                                        Forrest Gump    Romance
# 176086                                        Forrest Gump      Drama
# 115746                                       The Godfather      Drama
# 115745                                       The Godfather      Crime
# 207726                                          The Matrix     Action
# 207727                                          The Matrix     Sci-Fi
# 192125   The Lord of the Rings: The Fellowship of the Ring  Adventure
# 192126   The Lord of the Rings: The Fellowship of the Ring      Drama
# 192124   The Lord of the Rings: The Fellowship of the Ring     Action
# 254844       The Lord of the Rings: The Return of the King     Action
# 254845       The Lord of the Rings: The Return of the King  Adventure
# 254846       The Lord of the Rings: The Return of the King      Drama
# 688949                                        Interstellar      Drama
# 688948                                        Interstellar  Adventure
# 688950                                        Interstellar     Sci-Fi
# 254847               The Lord of the Rings: The Two Towers     Action
# 254849               The Lord of the Rings: The Two Towers      Drama
# 254848               The Lord of the Rings: The Two Towers  Adventure
# 1187895                              The Dark Knight Rises      Crime
# 1187896                              The Dark Knight Rises      Drama
# 1187894                              The Dark Knight Rises     Action
# 182817                                               Se7en      Crime
# 182819                                               Se7en    Mystery
# 182818                                               Se7en      Drama
# 1730222                                   Django Unchained    Western
# 1730221                                   Django Unchained      Drama
# 260588                                           Gladiator     Action
# 260590                                           Gladiator      Drama
# 260589                                           Gladiator  Adventure
# 166456                            The Silence of the Lambs      Crime
# 166457                            The Silence of the Lambs      Drama
# 166458                            The Silence of the Lambs   Thriller
# 173696                                    Schindler's List    History
# 173694                                    Schindler's List  Biography
# 173695                                    Schindler's List      Drama
# 513194                                       Batman Begins     Action
# 513196                                       Batman Begins      Drama
# 513195                                       Batman Begins      Crime
# 192275                                 Saving Private Ryan        War
# 192274                                 Saving Private Ryan      Drama
# 497699                                Inglourious Basterds      Drama
# 497698                                Inglourious Basterds  Adventure
# 497700                                Inglourious Basterds        War
# 127830                                           Star Wars  Adventure
# 127831                                           Star Wars    Fantasy
# 127829                                           Star Wars     Action
# 120085                              The Godfather: Part II      Crime
# 120086                              The Godfather: Part II      Drama
# 646436                                        The Prestige      Drama
# 646437                                        The Prestige    Mystery
#
#          averageRating   numVotes   POP SCORE
# 178228             9.3  2569002.0  23891718.6
# 628982             9.1  2534021.0  23059591.1
# 628983             9.1  2534021.0  23059591.1
# 628984             9.1  2534021.0  23059591.1
# 1230027            8.8  2254701.0  19841368.8
# 1230025            8.8  2254701.0  19841368.8
# 1230026            8.8  2254701.0  19841368.8
# 213498             8.8  2021525.0  17789420.0
# 177822             8.9  1972078.0  17551494.2
# 177823             8.9  1972078.0  17551494.2
# 176087             8.8  1981606.0  17438132.8
# 176086             8.8  1981606.0  17438132.8
# 115746             9.2  1768712.0  16272150.4
# 115745             9.2  1768712.0  16272150.4
# 207726             8.7  1849023.0  16086500.1
# 207727             8.7  1849023.0  16086500.1
# 192125             8.9  1789125.0  15923212.5
# 192126             8.9  1789125.0  15923212.5
# 192124             8.9  1789125.0  15923212.5
# 254844             9.0  1767391.0  15906519.0
# 254845             9.0  1767391.0  15906519.0
# 254846             9.0  1767391.0  15906519.0
# 688949             8.7  1712990.0  14903013.0
# 688948             8.7  1712990.0  14903013.0
# 688950             8.7  1712990.0  14903013.0
# 254847             8.8  1596717.0  14051109.6
# 254849             8.8  1596717.0  14051109.6
# 254848             8.8  1596717.0  14051109.6
# 1187895            8.4  1640491.0  13780124.4
# 1187896            8.4  1640491.0  13780124.4
# 1187894            8.4  1640491.0  13780124.4
# 182817             8.6  1575360.0  13548096.0
# 182819             8.6  1575360.0  13548096.0
# 182818             8.6  1575360.0  13548096.0
# 1730222            8.5  1484557.0  12618734.5
# 1730221            8.5  1484557.0  12618734.5
# 260588             8.5  1445608.0  12287668.0
# 260590             8.5  1445608.0  12287668.0
# 260589             8.5  1445608.0  12287668.0
# 166456             8.6  1377426.0  11845863.6
# 166457             8.6  1377426.0  11845863.6
# 166458             8.6  1377426.0  11845863.6
# 173696             9.0  1308967.0  11780703.0
# 173694             9.0  1308967.0  11780703.0
# 173695             9.0  1308967.0  11780703.0
# 513194             8.3  1416076.0  11753430.8
# 513196             8.3  1416076.0  11753430.8
# 513195             8.3  1416076.0  11753430.8
# 192275             8.6  1338294.0  11509328.4
# 192274             8.6  1338294.0  11509328.4
# 497699             8.3  1384899.0  11494661.7
# 497698             8.3  1384899.0  11494661.7
# 497700             8.3  1384899.0  11494661.7
# 127830             8.6  1314458.0  11304338.8
# 127831             8.6  1314458.0  11304338.8
# 127829             8.6  1314458.0  11304338.8
# 120085             9.0  1223575.0  11012175.0
# 120086             9.0  1223575.0  11012175.0
# 646436             8.5  1286709.0  10937026.5
# 646437             8.5  1286709.0  10937026.5

# %%
titleSRTDavrate = titlesBasicsRatings.sort_values( by=['averageRating'], ascending= False )
titleSRTDavrate.head(50)
# Out:
#               tconst                                       primaryTitle  \
# 3968548   tt12740466                                              Feast
# 11715430   tt6826364            Khatri Plans to Reveal Ishwari's Secret
# 11715428   tt6826362                 Sona finds out Ishwari's new house
# 11715427   tt6826360                    Sona finds out Ishwari's secret
# 11715426   tt6826360                    Sona finds out Ishwari's secret
# 11715425   tt6826358                                  Sona meets Khatri
# 11715424   tt6826358                                  Sona meets Khatri
# 11715402   tt6826316            Sona plans to find about Ishwari's past
# 11715401   tt6826316            Sona plans to find about Ishwari's past
# 11715391   tt6826296             Dev accuses Sona of being a bad mother
# 11715390   tt6826296             Dev accuses Sona of being a bad mother
# 11715385   tt6826290               DevAkshi and Suhana at Ishwari Nivas
# 11715384   tt6826290               DevAkshi and Suhana at Ishwari Nivas
# 5299231   tt14303266                                             Havada
# 5299232   tt14303266                                             Havada
# 2756168    tt1129461                                               Okay
# 2756167    tt1129461                                               Okay
# 4896467    tt1381815                                        Love Sophie
# 11715376   tt6826280                 Asha Locks Dev and Bijoy in a Room
# 11715375   tt6826280                 Asha Locks Dev and Bijoy in a Room
# 11715374   tt6826278      Dev Is Jealous to See Jatin with His Daughter
# 11715373   tt6826278      Dev Is Jealous to See Jatin with His Daughter
# 11715372   tt6826276  Asha asks Dev and Sona to sort out their diffe...
# 11715371   tt6826276  Asha asks Dev and Sona to sort out their diffe...
# 11715368   tt6826272  Bijoy Blames Dev for Stealing Ronita's Jewellwery
# 11715367   tt6826272  Bijoy Blames Dev for Stealing Ronita's Jewellwery
# 11715363   tt6826268           Ronita Confesses Her Feelings to Saurabh
# 11715429   tt6826362                 Sona finds out Ishwari's new house
# 11715431   tt6826364            Khatri Plans to Reveal Ishwari's Secret
# 11715361   tt6826266                   Bijoy forces Dev to wear a Dhoti
# 11715438   tt6826374                               Police Arrest Khatri
# 5296726   tt14300190                                     Episode #1.141
# 5296727   tt14300190                                     Episode #1.141
# 6470819   tt15752272  Eric Martsolf talks with BJ Korros about Starr...
# 11717259   tt6829128  Laura Ellen Wilson Taking the Thriller Genre t...
# 2761403   tt11300762                                        In Thin Air
# 2761402   tt11300762                                        In Thin Air
# 6470516   tt15751908                        Leave when you want to stay
# 6469463   tt15750468                                           Loveline
# 6469462   tt15750468                                           Loveline
# 6469353   tt15750352                                     Now I Am Alone
# 6979992   tt16606780                                 Mural of the Story
# 6979993   tt16606780                                 Mural of the Story
# 193323     tt0111263                                       Spiral Tribe
# 506548     tt0324200                                 Tenkisti iz Nustra
# 7473066   tt18212948                                          Aftermath
# 6984689   tt16611502                                             Hævnen
# 6984690   tt16611502                                             Hævnen
# 6984691   tt16611502                                             Hævnen
# 11463727   tt6475158        Earlina Gilford Weaver: A True Inspiration!
#
#                genres  averageRating  numVotes  POP SCORE
# 3968548        Comedy           10.0      30.0      300.0
# 11715430        Drama           10.0       5.0       50.0
# 11715428        Drama           10.0       5.0       50.0
# 11715427      Romance           10.0       5.0       50.0
# 11715426        Drama           10.0       5.0       50.0
# 11715425      Romance           10.0       5.0       50.0
# 11715424        Drama           10.0       5.0       50.0
# 11715402      Romance           10.0       5.0       50.0
# 11715401        Drama           10.0       5.0       50.0
# 11715391      Romance           10.0       6.0       60.0
# 11715390        Drama           10.0       6.0       60.0
# 11715385      Romance           10.0       5.0       50.0
# 11715384        Drama           10.0       5.0       50.0
# 5299231         Drama           10.0      89.0      890.0
# 5299232       Mystery           10.0      89.0      890.0
# 2756168         Music           10.0      53.0      530.0
# 2756167     Biography           10.0      53.0      530.0
# 4896467         Short           10.0       6.0       60.0
# 11715376      Romance           10.0       5.0       50.0
# 11715375        Drama           10.0       5.0       50.0
# 11715374      Romance           10.0       5.0       50.0
# 11715373        Drama           10.0       5.0       50.0
# 11715372      Romance           10.0       5.0       50.0
# 11715371        Drama           10.0       5.0       50.0
# 11715368      Romance           10.0       5.0       50.0
# 11715367        Drama           10.0       5.0       50.0
# 11715363      Romance           10.0       5.0       50.0
# 11715429      Romance           10.0       5.0       50.0
# 11715431      Romance           10.0       5.0       50.0
# 11715361      Romance           10.0       5.0       50.0
# 11715438        Drama           10.0       5.0       50.0
# 5296726         Drama           10.0       6.0       60.0
# 5296727         Music           10.0       6.0       60.0
# 6470819     Talk-Show           10.0      14.0      140.0
# 11717259    Talk-Show           10.0      29.0      290.0
# 2761403         Short           10.0      26.0      260.0
# 2761402       Fantasy           10.0      26.0      260.0
# 6470516   Documentary           10.0       6.0       60.0
# 6469463         Short           10.0       7.0       70.0
# 6469462         Drama           10.0       7.0       70.0
# 6469353         Short           10.0       6.0       60.0
# 6979992   Documentary           10.0      11.0      110.0
# 6979993         Short           10.0      11.0      110.0
# 193323          Short           10.0       7.0       70.0
# 506548          Short           10.0      12.0      120.0
# 7473066      Thriller           10.0       7.0       70.0
# 6984689         Drama           10.0       7.0       70.0
# 6984690         Short           10.0       7.0       70.0
# 6984691      Thriller           10.0       7.0       70.0
# 11463727    Talk-Show           10.0      28.0      280.0

# %%
titleSRTDpop.value_counts(['genres']).head(5)
# Out:
# genres
# Short          916010
# Drama          526563
# Documentary    327226
# Comedy         324403
# Adult          101785
# dtype: int64

# %%
top5 = titleSRTDpop.head(14)

# %%
top5.value_counts(['genres'])
# Out:
# genres
# Drama        6
# Crime        3
# Action       2
# Adventure    1
# Romance      1
# Sci-Fi       1
# dtype: int64

# %%
top5byscore = top5[['genres', 'POP SCORE']].sort_values(by= 'POP SCORE')

# %%
groupedtop5 = top5byscore.groupby(by="genres").sum()

# %%
#GENRES BY POPULARITY AMONG TOP5 POPULAR MOVIES

groupedtop5.sort_values(by= 'POP SCORE', ascending = False)
# Out:
#              POP SCORE
# genres
# Drama      116002507.1
# Crime       56883235.7
# Action      42900959.9
# Adventure   19841368.8
# Sci-Fi      19841368.8
# Romance     17438132.8
